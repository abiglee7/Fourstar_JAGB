# %%
from prep_photometry import check_2mass_zps
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## IC 1613

# %%
check_2mass_zps(directory='/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/IC 1613/*/*/*',
               ra_list = [11,11,11,11,11,9,9,9], dec_list = [12,12,12,12,12,10,10,10])
# Out:
# ['/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/IC 1613/JHK/2011_11_03/2011_11_03', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/IC 1613/JHK/2011_10_04/2011_10_04', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/IC 1613/JHK/2017_7_01/2017_7_01', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/IC 1613/JHK/2011_9_07/2011_9_07', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/IC 1613/JHK/2017_7_02/2017_7_02', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/IC 1613/J/2013_10_12/2013_10_12', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/IC 1613/J/2013_10_13/2013_10_13', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/IC 1613/J/2021_9_16/2021_9_16']
# Median Offset: -0.042 +/- 0.026 mag
# Median Offset: -0.019 +/- 0.016 mag
# Median Offset: -0.027 +/- 0.012 mag
# Median Offset: -0.016 +/- 0.005 mag
# Median Offset: -0.009 +/- 0.003 mag
# Median Offset: 0.018 +/- 0.0 mag
# ...

# %% [markdown]
# ## Sex A

# %%
check_2mass_zps(directory='/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/Sextans A/*/*/*',
               ra_list = [9,9,1], dec_list = [10,10,2])
# Out:
# ['/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/Sextans A/JH/2021_01_03/jh4star_Sextans_A_1.radec', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/Sextans A/JK/2022_02_12/jk4star_Sextans_A.radec', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/Sextans A/JHK/2013_01_03/Sextans_A_2013_01_03_JHK.txt']
# Median Offset: -0.019 +/- 0.01 mag
# Median Offset: 0.02 +/- 0.014 mag
# No matches found

# %% [markdown]
# ## Sextans B

# %%
check_2mass_zps(directory='/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/Sextans B/*/*/*',
               ra_list = [9,1], dec_list = [10,2])
# Out:
# ['/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/Sextans B/JK/2022_02_13/jk4star_Sextans_B.radec', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/Sextans B/JHK/2013_01_04/Sextans_B_2013_01_04_JHK.txt']
# Median Offset: -0.027 +/- 0.016 mag
# No matches found

# %% [markdown]
# ## NGC 55

# %%
check_2mass_zps(directory='/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC55/*/*/*',
               ra_list = [1,1,11], dec_list = [2,2,12],max_mag = 16)
# Out:
# ['/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC55/JHK/2011_11_03/NGC0055_2011_11_03_JHK.txt', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC55/JHK/2011_09_07/NGC0055_2011_09_07_JHK.txt', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC55/JHK/2011_10_04/jhk4star_NGC0055.radec']
# No matches found after cleaning
# Median Offset: -- +/- nan mag
# No matches found after cleaning
# Median Offset: -- +/- nan mag
# No matches found after cleaning
# Median Offset: -- +/- nan mag

# %% [markdown]
# # NGC 300

# %%
check_2mass_zps(directory='/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC300/*/*/*',
               ra_list = [9,9,11,11,11], dec_list = [10,10,12,12,12],mask=[0,5])
# Out:
# ['/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC300/H/2011_09_08/image_H.txt', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC300/JK/2011_09_09/jk4star_NGC_300.radec', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC300/JK/2021_09_17/jk4star_NGC_300.radec', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC300/JHK/2011_11_03/jhk4star_NGC_300.radec', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC300/JHK/2011_10_05/jhk4star_NGC_300.radec', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC300/JHK/2019_11_14/jhk4star_NGC_300.radec', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC300/K/2011_10_04/image_Ks.txt']
# Median Offset: -0.07 +/- 0.0 mag
# No matches found after cleaning
# Median Offset: -- +/- nan mag
# Median Offset: -0.001 +/- 0.0 mag
# Median Offset: 0.032 +/- 0.0 mag
# No matches found

# %% [markdown]
# ## NGC 3109

# %%
check_2mass_zps(directory='/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC3109/*/*/*',
               ra_list = [9,9,9,9,1,1], dec_list = [10,10,10,10,2,2])
# Out:
# ['/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC3109/JH/2021_04_01/jh4star_NGC3109.radec', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC3109/JH/2017_07_02/jh4star_NGC3109.radec', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC3109/JK/2022_03_16/jk4star_NGC_3109.radec', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC3109/JK/2022_02_12/jk4star_NGC_3109.radec', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC3109/JHK/2011_11_03/NGC3109_2011_11_03_JHK.txt', '/Users/abigaillee/Photometry/JAGB stars MISC/Fourstar/Raw/NGC3109/JHK/2012_05_03/NGC3109_2012_05_03_JHK.txt']
# Median Offset: 0.024 +/- 0.0 mag
# No matches found after cleaning
# Median Offset: -- +/- nan mag
# Median Offset: 0.069 +/- 0.022 mag
# Median Offset: 0.075 +/- 0.046 mag
# No matches found
