# %% [markdown]
# Clean all individual epochs of all 12 galaxies in this sample:
# NGC 6822, IC 1613, NGC 3109, Sextans B, Sextans A, NGC 300, NGC 55, NGC 247, Cen A, NGC 5253, NGC 1313, M83.
#
# Note that some epochs do not CMDs because they only have J band data.
#
# Author: Abigail J. Lee

# %%
from prep_photometry import combine

# %% [markdown]
# ## 1. IC 1613

# %%
combine(jcol=3, jcolsharp=10,jcolerr=4,jcolchi=9,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.015, A_err=0.003, p_err=17.6,
                         const_sharp=0.14, A_sharp = 0.03, p_sharp = 18, 
                          const_chi=0.055, p_chi=15.5,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='IC 1613', folder_name='IC 1613/JHK/2011_9_07', date='2011-09-07',
                       secondcol=7,secondcolname='K')
combine(jcol=3, jcolsharp=10,jcolerr=4,jcolchi=9,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.015, A_err=0.003, p_err=17.3,
                         const_sharp=0.14, A_sharp = 0.03, p_sharp = 18.5, 
                          const_chi=0.065, p_chi=15.5,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='IC 1613', folder_name='IC 1613/JHK/2011_10_04', date='2011-10-04',
       secondcol=7,secondcolname='K')
combine(jcol=3, jcolsharp=10,jcolerr=4,jcolchi=9,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.015, A_err=0.003, p_err=17.3,
                         const_sharp=0.14, A_sharp = 0.03, p_sharp = 20, 
                          const_chi=0.06, p_chi=15.5,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='IC 1613', folder_name='IC 1613/JHK/2011_11_03', date='2011-11-03',
       secondcol=7,secondcolname='K')
combine(jcol=3, jcolsharp=10,jcolerr=4,jcolchi=9,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.015, A_err=0.003, p_err=17,
                         const_sharp=0.13, A_sharp = 0.03, p_sharp =18., 
                          const_chi=0.08, p_chi=16,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='IC 1613', folder_name='IC 1613/JHK/2017_7_01',
                            date='2017-07-01',secondcol=7,secondcolname='K')
combine(jcol=3, jcolsharp=10,jcolerr=4,jcolchi=9,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.015, A_err=0.003, p_err=16.2,
                         const_sharp=0.18, A_sharp = 0.01, p_sharp = 19.5, 
                          const_chi=0.02, p_chi=14,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='IC 1613', folder_name='IC 1613/JHK/2017_7_02',
                            date='2017-07-02',secondcol=7,secondcolname='K')


                    
combine(jcol=3, jcolsharp=8,jcolerr=4,jcolchi=7,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.02, A_err=0.003, p_err=18.5,
                         const_sharp=0.1, A_sharp = 0.025, p_sharp = 20.1, 
                          const_chi=0.06, p_chi=14,
                         plot=True,
                         jlower=16, jupper=24,save_fig=True,name='IC 1613',folder_name='IC 1613/J/2013_10_12', 
       date='2013-10-12')
                    
combine(jcol=3, jcolsharp=8,jcolerr=4,jcolchi=7,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.02, A_err=0.003, p_err=18.2,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 20, 
                          const_chi=0.06, p_chi=14,
                         plot=True,
                         jlower=16, jupper=24,save_fig=True,name='IC 1613',folder_name='IC 1613/J/2013_10_13', 
       date='2013-10-13')
                    
combine(jcol=3, jcolsharp=8,jcolerr=4,jcolchi=7,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.02, A_err=0.003, p_err=17.65,
                         const_sharp=0.1, A_sharp = 0.06, p_sharp =19, 
                          const_chi=0.08, p_chi=14,
                         plot=True,
                         jlower=15, jupper=22,save_fig=True,name='IC 1613',folder_name='IC 1613/J/2021_9_16', 
       date='2021-09-16')

# %% [markdown]
# ## 2. NGC 3109

# %%
combine(jcol=3, jcolsharp=8,jcolerr=4,jcolchi=7,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=17,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 18., 
                          const_chi=0.04, p_chi=14,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='NGC3109', folder_name='NGC3109/JH/2017_07_02', date='2017-07-02',
       secondcolname='H',secondcol=5)
combine(jcol=3, jcolsharp=8,jcolerr=4,jcolchi=7,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=17.5,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 20., 
                          const_chi=0.035, p_chi=14,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='NGC3109', folder_name='NGC3109/JH/2021_04_01', date='2021-04-01',
       secondcolname='H',secondcol=5)

combine(jcol=3, jcolsharp=8,jcolerr=4,jcolchi=7,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=18,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 19.5, 
                          const_chi=0.035, p_chi=14,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='NGC3109', folder_name='NGC3109/JK/2022_02_12', date='2022-02-12',
       secondcolname='K',secondcol=5)



combine(jcol=3, jcolsharp=6,jcolerr=4,jcolchi=5,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=18,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 19.5, 
                          const_chi=0.035, p_chi=14,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='NGC3109', folder_name='NGC3109/JHK/2011_11_03', date='2011-11-03',
       secondcolname='K',secondcol=11)


combine(jcol=3, jcolsharp=6,jcolerr=4,jcolchi=5,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=18,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 19.5, 
                          const_chi=0.035, p_chi=14,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='NGC3109', folder_name='NGC3109/JHK/2012_05_03', date='2012-05-03',
       secondcolname='K',secondcol=11)


combine(jcol=3, jcolsharp=8,jcolerr=4,jcolchi=7,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=17.5,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 19.5, 
                          const_chi=0.04, p_chi=14,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='NGC3109', folder_name='NGC3109/JK/2022_03_16', date='2022-03-16',
       secondcolname='K',secondcol=5)

# %% [markdown]
# ## 3. Sextans B

# %%
combine(jcol=3, jcolsharp=6,jcolerr=4,jcolchi=5,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=18,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 19., 
                          const_chi=0.03, p_chi=14,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='Sextans B', folder_name='Sextans B/JHK/2013_01_04', date='2013-01-04',
      secondcolname='K',secondcol=11 )

combine(jcol=3, jcolsharp=8,jcolerr=4,jcolchi=7,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=18,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 19., 
                          const_chi=0.03, p_chi=14,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='Sextans B', folder_name='Sextans B/JK/2022_02_13', date='2022-02-13',
       secondcolname='K',secondcol=5 )

# %% [markdown]
# ## 4. Sextans A

# %%
combine(jcol=3, jcolsharp=6,jcolerr=4,jcolchi=5,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=18.3,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 19, 
                          const_chi=0.02, p_chi=15,
                         plot=True,
                         jlower=16., jupper=23.,save_fig=True,name='Sextans A', folder_name='Sextans A/JHK/2013_01_03', date='2013-01-03',
       secondcolname='K',secondcol=11)

combine(jcol=3, jcolsharp=8,jcolerr=4,jcolchi=7,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=18.3,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 18., 
                          const_chi=0.025, p_chi=14,
                         plot=True,
                         jlower=16., jupper=23.,save_fig=True,name='Sextans A', folder_name='Sextans A/JH/2021_01_03', date='2021-01-03',
       secondcolname='H',secondcol=5)

combine(jcol=3, jcolsharp=8,jcolerr=4,jcolchi=7,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=17.8,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 20, 
                          const_chi=0.035, p_chi=14,
                         plot=True,
                         jlower=16., jupper=23.,save_fig=True,name='Sextans A', folder_name='Sextans A/JK/2022_02_12', date='2022-02-12',
       secondcolname='K',secondcol=5)

# %% [markdown]
# ## 5. NGC 300

# %%
combine(jcol=13, jcolsharp=18,jcolerr=14,jcolchi=17,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=15,
                         const_sharp=0.15, A_sharp = 0.03, p_sharp = 19., 
                          const_chi=0.1, p_chi=14,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='NGC 300', folder_name='NGC300/H/2011_09_08', date='2011-09-08',
       )

combine(jcol=13, jcolsharp=18,jcolerr=14,jcolchi=17,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=15,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 17, 
                          const_chi=0.07, p_chi=14,
                         plot=True,
                         jlower=15., jupper=22.,save_fig=True,name='NGC 300', folder_name='NGC300/K/2011_10_04', date='2011-10-04')

combine(jcol=3, jcolsharp=10,jcolerr=4,jcolchi=9,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.03, A_err=0.0025, p_err=18,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 22, 
                          const_chi=0.08, p_chi=15,
                         plot=True,
                         jlower=16., jupper=23.,save_fig=True,name='NGC 300', folder_name='NGC300/JHK/2011_10_05', date='2011-10-05',
       secondcolname='K',secondcol=7)
combine(jcol=3, jcolsharp=10,jcolerr=4,jcolchi=9,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=18,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 22, 
                          const_chi=0.05, p_chi=15,
                         plot=True,
                         jlower=16., jupper=23.,save_fig=True,name='NGC 300', folder_name='NGC300/JHK/2011_11_03', date='2011-11-03',
       secondcolname='K',secondcol=7)

combine(jcol=3, jcolsharp=10,jcolerr=4,jcolchi=9,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=17.2,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 20, 
                          const_chi=0.2, p_chi=14,
                         plot=True,
                         jlower=16., jupper=23.,save_fig=True,name='NGC 300', folder_name='NGC300/JHK/2019_11_14', date='2019-11-14',
       secondcolname='K',secondcol=7)

combine(jcol=3, jcolsharp=8,jcolerr=4,jcolchi=7,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=16.5,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 22, 
                          const_chi=0.07, p_chi=15,
                         plot=True,
                         jlower=16., jupper=23.,save_fig=True,name='NGC 300', folder_name='NGC300/JK/2011_09_09', date='2011-09-09',
       secondcolname='K',secondcol=5)

combine(jcol=3, jcolsharp=8,jcolerr=4,jcolchi=7,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=17.5,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 21, 
                          const_chi=0.04, p_chi=14,
                         plot=True,
                         jlower=16., jupper=23.,save_fig=True,name='NGC 300', folder_name='NGC300/JK/2021_09_17', date='2021-09-17',
       secondcolname='K',secondcol=5)

# %% [markdown]
# ## 6. NGC 55

# %%
# combine(jcol=3, jcolsharp=6,jcolerr=4,jcolchi=5,
#                           cleansharp=True, cleanerr=True,cleanchi=True,
#                           const_err=0.01, A_err=0.0025, p_err=18,
#                          const_sharp=0.1, A_sharp = 0.03, p_sharp = 19., 
#                           const_chi=0.04, p_chi=14,
#                          plot=True,
#                          jlower=16., jupper=23.,save_fig=True,name='NGC55', folder_name='NGC55/JHK/2011_09_07', date='2011-09-07',
#        secondcolname='K',secondcol=11)

# combine(jcol=3, jcolsharp=10,jcolerr=4,jcolchi=9,
#                           cleansharp=True, cleanerr=True,cleanchi=True,
#                           const_err=0.01, A_err=0.0025, p_err=18,
#                          const_sharp=0.1, A_sharp = 0.03, p_sharp = 17.5, 
#                           const_chi=0.04, p_chi=14,
#                          plot=True,
#                          jlower=16., jupper=23.,save_fig=True,name='NGC55', folder_name='NGC55/JHK/2011_10_04', date='2011-10-04',
#        secondcolname='K',secondcol=7)
combine(jcol=3, jcolsharp=6,jcolerr=4,jcolchi=5,
                          cleansharp=True, cleanerr=True,cleanchi=True,
                          const_err=0.01, A_err=0.0025, p_err=17.3,
                         const_sharp=0.1, A_sharp = 0.03, p_sharp = 19.5, 
                          const_chi=0.08, p_chi=15,
                         plot=True,
                         jlower=16., jupper=23.,save_fig=True,name='NGC55', folder_name='NGC55/JHK/2011_11_03', date='2011-11-03',
       secondcolname='K',secondcol=11)
